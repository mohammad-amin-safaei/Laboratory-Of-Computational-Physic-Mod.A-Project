# %% [markdown]
# # Load Data

# %%
from utils import *
import numpy as np
import matplotlib.pyplot as plt

data_dir = "physionet.org/files/nsr2db/1.0.0"
rr_data = load_rr_intervals(data_dir)
# Out:
#   nsr001: 106464 beats, mean HR = 79.0 bpm
#   nsr002: 111334 beats, mean HR = 79.5 bpm
#   nsr003: 97585 beats, mean HR = 69.3 bpm
#   nsr004: 97821 beats, mean HR = 70.5 bpm
#   nsr005: 116773 beats, mean HR = 81.7 bpm
#   nsr006: 102662 beats, mean HR = 74.3 bpm
#   nsr007: 106792 beats, mean HR = 76.1 bpm
#   nsr008: 107739 beats, mean HR = 75.4 bpm
#   nsr009: 102861 beats, mean HR = 71.8 bpm
#   nsr010: 96252 beats, mean HR = 70.1 bpm
#   nsr011: 115900 beats, mean HR = 81.5 bpm
#   nsr012: 98905 beats, mean HR = 69.1 bpm
#   nsr013: 115757 beats, mean HR = 82.3 bpm
#   nsr014: 111896 beats, mean HR = 78.2 bpm
#   nsr015: 100961 beats, mean HR = 75.9 bpm
#   nsr016: 94767 beats, mean HR = 77.2 bpm
#   nsr017: 100959 beats, mean HR = 70.4 bpm
#   nsr018: 107982 beats, mean HR = 77.3 bpm
#   nsr019: 122822 beats, mean HR = 85.7 bpm
#   nsr020: 136481 beats, mean HR = 97.7 bpm
#   nsr021: 103875 beats, mean HR = 72.5 bpm
#   nsr022: 81720 beats, mean HR = 57.8 bpm
# ...

# %% [markdown]
# # Step 1: build the cumulative time series B(i) from the detrended and normalised heart beat time series b(i)

# %%
# Dictionaries to store the normalized b(i) and cumulative B(i) time series
b_data = {}
B_data = {}

for record_name, rr in rr_data.items():
    # 1. Calculate mean (\mu) and standard deviation (\sigma)
    mu = np.mean(rr)
    sigma = np.std(rr)
    
    # 2. Normalize the RR intervals to get b(i)
    b_i = (rr - mu) / sigma
    b_data[record_name] = b_i
    
    # 3. Integrate (cumulative sum) to get B(i)
    B_i = np.cumsum(b_i)
    B_data[record_name] = B_i

first_n = 4 # Plot the first_n random walks
records_to_plot = list(B_data.keys())[:first_n]

plt.figure(figsize=(10, 5))

for record_name in records_to_plot:
    plt.plot(B_data[record_name], lw=0.8, label=f"{record_name}")

plt.title("Cumulative Time Series B(i) for Multiple Records")
plt.xlabel("Beat number (i)")
plt.ylabel("B(i)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 2 & 3: Polynomial Detrending and Calculating Increments
#
# The paper describes a specific sliding-window technique (related to Detrended Fluctuation Analysis, DFA):
# 1. Take a sliding window of size $2s$.
# 2. Fit a polynomial (the paper uses 3rd order) to the data in that window.
# 3. Subtract the polynomial trend to get the residual fluctuations, $B^*(i)$.
# 4. Calculate the increment across scale $s$ within that window: $\Delta_s B = B^*(s) - B^*(0)$.
# 5. Slide the window forward by 1 beat and repeat.

# %%
def get_detrended_increments(B_array: np.ndarray, s: int, order: int=3):
    """
    Extracts detrended increments \\Delta_s B(i) using a sliding window.
    
    B_array: Cumulative time series array
    s: time scale (number of beats)
    order: polynomial order for detrending (paper uses 3rd order)
    """
    N = len(B_array)
    window_size = 2 * s
    increments = []
    
    # x-axis for our local window
    x = np.arange(window_size)
    
    # We slide the window one beat at a time
    for i in range(N - window_size + 1):
        # 1. Grab the local segment of size 2s
        window_data = B_array[i : i + window_size]
        
        # 2. Fit an 'order'-th degree polynomial
        coeffs = np.polyfit(x, window_data, order)
        poly_trend = np.polyval(coeffs, x)
        
        # 3. Calculate deviation from the polynomial fit (B*)
        B_star = window_data - poly_trend
        
        # 4. Calculate the increment at scale s 
        # (In local coordinates, from index 0 to index s)
        delta_B = B_star[s] - B_star[0]
        
        increments.append(delta_B)
        
    return np.array(increments)

# Let's test it on a single record at a single scale (e.g., s = 64 beats)
s_test = 64
test_record = list(B_data.keys())[0]
B_test = B_data[test_record]

print(f"Calculating detrended increments for {test_record} at scale s={s_test}...")
delta_B_s64 = get_detrended_increments(B_test, s=s_test, order=3)

# Plot the resulting increments
plt.figure(figsize=(10, 4))
plt.plot(delta_B_s64, lw=0.5, color='black', alpha=0.7)
plt.title(rf"Detrended Increments $\Delta_s B(i)$ for {test_record} (s={s_test})")
plt.xlabel("Beat number (i)")
plt.ylabel(rf"$\Delta_{{{s_test}}} B$")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Calculating detrended increments for nsr001 at scale s=64...

# %% [markdown]
# ## Modified addition for Step 2: Local polynomial trend figure
#
# The next cell was **moved into Step 2** so the polynomial detrending is explicit.
# It picks one sample window of length $2s$, fits the local polynomial trend, plots $B(i)$, the fitted trend, and the detrended signal $B^*(i)$, and marks the two points used to compute the increment $\Delta_s B$.

# %%
# modified: visualize Task 2 explicitly on one local window
sample_record = list(B_data.keys())[0]  
sample_s = 64  
sample_order = 3  
sample_start = 500  

B_sample = B_data[sample_record]  
window_size = 2 * sample_s  
x_local = np.arange(window_size)  
window_data = B_sample[sample_start: sample_start + window_size]  

coeffs_local = np.polyfit(x_local, window_data, sample_order)  
poly_local = np.polyval(coeffs_local, x_local)  
B_star_local = window_data - poly_local  
delta_local = B_star_local[sample_s] - B_star_local[0]  
#plt.plot(x_local,B_sample[0:128])
fig, axes = plt.subplots(2, 1, figsize=(11, 7), sharex=True)  

axes[0].plot(x_local, window_data, label='Local window of B(i)', lw=2)  
axes[0].plot(x_local, poly_local, '--', label='3rd-order polynomial trend', lw=2) 
axes[0].axvline(sample_s, color='gray', ls=':', alpha=0.8)  
axes[0].set_title(f"Explicit view for {sample_record}, window size = 2s = {window_size}")  
axes[0].set_ylabel("B(i) in local window")  
axes[0].legend()  
axes[0].grid(True, alpha=0.3)  

axes[1].plot(x_local, B_star_local, color='black', lw=1.5, label=r'Detrended signal $B^*(i)$') 
axes[1].scatter([0, sample_s], [B_star_local[0], B_star_local[sample_s]], color='red', zorder=5, label='Increment endpoints')  
axes[1].axvline(sample_s, color='gray', ls=':', alpha=0.8)  
axes[1].set_title(rf" Detrended fluctuation and increment $\Delta_{{{sample_s}}}B = {delta_local:.3f}$") 
axes[1].set_xlabel("Local index inside the 2s window")  
axes[1].set_ylabel(r"$B^*(i)$")  
axes[1].legend()  
axes[1].grid(True, alpha=0.3)  

plt.tight_layout()  
plt.show()

# %% [markdown]
# To really understand what just happened, read this:
#
# Imagine the cumulative heartbeat series $B(i)$ as a **bumpy mountain range**.
#
# The massive mountains and deep valleys represent slow, macroscopic behavioral changes—like a person waking up, exercising, or falling asleep. The tiny, jagged rocks on the surface represent the intrinsic, beat-to-beat fluctuations of the nervous system. Our goal is to measure the size of these "rocks" over a specific distance $s$ (e.g., 64 steps). If we simply measure our altitude change every 64 steps, our math will be completely overwhelmed by the steep slope of the mountain itself.
#
# So, we use a clever mathematical trick: we place a sliding window over a section of the path ($2s$), and fit a flexible, smooth curve (the 3rd-order polynomial) to exactly match the shape of the mountain in that specific window. By subtracting that smooth curve from our data, we mathematically **flatten the ground**, temporarily erasing the mountain entirely. Only then, on this newly flattened ground, do we measure the change in height ($\Delta_s B$) over our distance $s$. By sliding this window one beat at a time, we successfully strip away all the massive, slow trends of daily life, leaving behind only the pure, isolated nervous system fluctuations we need to study.

# %% [markdown]
# # Step 4: Build the PDF and find the Fat Tails

# %% [markdown]
# If heart rate fluctuations were purely random (like tossing a coin or thermal white noise), the increments we just calculated would perfectly follow a Gaussian (bell curve) distribution. Extreme fluctuations would be statistically impossible. But as we saw in last plot, there are massive spikes. To prove these aren't just outliers, we are going to build a Probability Density Function (PDF) of those increments.
#
# To compare it fairly, we first standardize the data (divide by the standard deviation so the variance is 1). Then, we will fit it with a standard Gaussian, and a non-Gaussian q-Gaussian (which allows for "fat tails"). We will plot this on a logarithmic y-axis because that is the only way to clearly see what happens at the extreme edges (the "tails") of the distribution.

# %%
from scipy.optimize import curve_fit

# 1. Standardize the increments (mean = 0, standard deviation = 1)
std_increments = delta_B_s64 / np.std(delta_B_s64)

# 2. Calculate the Histogram (PDF)
counts, bin_edges = np.histogram(std_increments, bins=150, density=True)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Filter out empty bins so we don't take log(0)
mask = counts > 0
x_data = bin_centers[mask]
y_data = counts[mask]

# 3. Define the standard Gaussian (mean=0, std=1)
def gaussian(x):
    return (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)

# 4. Define the q-Gaussian (from Tsallis statistics)
def q_gaussian(x, A, beta, q):
    # The mathematical form for q-Gaussian
    # When q -> 1, this becomes a standard Gaussian
    # When q > 1, it develops "fat tails"
    return A * (1 - (1 - q) * beta * x**2)**(1 / (1 - q))

# 5. Fit the q-Gaussian to our data
# We provide initial guesses: A=0.4 (peak of Gaussian), beta=0.5, q=1.5
popt, pcov = curve_fit(q_gaussian, x_data, y_data, p0=[0.4, 0.5, 1.5])
A_fit, beta_fit, q_fit = popt

print(f"Fitted q-Gaussian parameters: A={A_fit:.3f}, beta={beta_fit:.3f}, q={q_fit:.3f}")

# 6. Plot the results on a Logarithmic scale
plt.figure(figsize=(8, 6))

# Plot the actual data as scatter points
plt.plot(x_data, y_data, 'o', markersize=4, color='black', alpha=0.6, label='Data PDF')

# Plot the theoretical Gaussian
x_plot = np.linspace(-15, 15, 500)
plt.plot(x_plot, gaussian(x_plot), '--', color='blue', lw=2, label='Gaussian (q=1)')

# Plot our fitted q-Gaussian
plt.plot(x_plot, q_gaussian(x_plot, *popt), '-', color='red', lw=2, 
         label=f'q-Gaussian fit (q={q_fit:.2f})')

plt.yscale('log') # This is crucial!
plt.xlim(-10, 10)
plt.ylim(1e-5, 1)

plt.title(f"Probability Density Function of Increments (s={s_test})")
plt.xlabel(r"Standardized Increment $\Delta_s B / \sigma$")
plt.ylabel(r"Probability Density $P(\Delta_s B)$")
plt.legend()
plt.grid(True, alpha=0.3, which="both", ls="--")
plt.tight_layout()
plt.show()
# Out:
# Fitted q-Gaussian parameters: A=0.611, beta=1.948, q=1.565

# %%
# modified: helper imports for the extended analysis
from scipy.stats import norm  
from scipy.optimize import curve_fit  

# keep the exact set of scales requested in the feedback
scales_to_analyze = [8, 16, 32, 64, 128, 256]  

# choose how many subjects to include in pooled analysis
max_records_for_pooling = min(10, len(B_data))  
selected_records = list(B_data.keys())[:max_records_for_pooling]  # 

print("modified: scales used =", scales_to_analyze)  
print("modified: records used for pooled analysis =", selected_records) 

#robust q-Gaussian with safe clipping to avoid invalid powers
def q_gaussian_safe(x, A, beta, q):  
    base = 1 - (1 - q) * beta * x**2  
    base = np.maximum(base, 1e-12)  
    return A * base ** (1 / (1 - q))  

#standardize data before PDF comparison
def standardize(x):  
    x = np.asarray(x)  
    return (x - np.mean(x)) / np.std(x)  

# build a smooth histogram-based PDF
def compute_pdf(x, bins=120, x_range=None):  
    counts, edges = np.histogram(x, bins=bins, range=x_range, density=True)  
    centers = 0.5 * (edges[:-1] + edges[1:])  
    mask = counts > 0  
    return centers[mask], counts[mask]  

# fit a q-Gaussian to standardized increments
def fit_q_gaussian(std_increments):  
    x_pdf, y_pdf = compute_pdf(std_increments, bins=150)  
    popt, _ = curve_fit(  
        q_gaussian_safe, x_pdf, y_pdf, 
        p0=[0.4, 0.5, 1.2],  
        bounds=([0.0, 0.0, 1.001], [10.0, 10.0, 2.95]),  
        maxfev=20000  
    )  
    y_q = q_gaussian_safe(x_pdf, *popt)  
    y_g = norm.pdf(x_pdf, loc=0, scale=1)  
    rss_q = np.sum((y_pdf - y_q)**2)  
    rss_g = np.sum((y_pdf - y_g)**2)  
    return x_pdf, y_pdf, popt, rss_g, rss_q
# Out:
# modified: scales used = [8, 16, 32, 64, 128, 256]
# modified: records used for pooled analysis = ['nsr001', 'nsr002', 'nsr003', 'nsr004', 'nsr005', 'nsr006', 'nsr007', 'nsr008', 'nsr009', 'nsr010']

# %% [markdown]
# ## Modified addition for Step 4: PDFs at several scales
#
# This cell extends the original single-scale PDF analysis to the requested scales $s=8,16,32,64,128,256$.
# It computes standardized increments for one subject and overlays their empirical PDFs to check how the distribution changes with scale.

# %%
# modified: compute standardized increments for one chosen record at several scales
single_record = list(B_data.keys())[0]  
single_subject_increments = {}  

for s in scales_to_analyze:  
    increments_s = get_detrended_increments(B_data[single_record], s=s, order=3) 
    single_subject_increments[s] = standardize(increments_s)  

#  plot PDFs at several scales for one subject
plt.figure(figsize=(10, 7))  
for s in scales_to_analyze:  
    x_pdf, y_pdf = compute_pdf(single_subject_increments[s], bins=120, x_range=(-8, 8))  
    plt.plot(x_pdf, y_pdf, marker='o', ms=3, lw=1, label=f"s={s}")  

plt.yscale("log")  
plt.xlim(-8, 8)  
plt.ylim(1e-4, 1)  
plt.title(f"modified: Standardized PDFs across scales for one subject ({single_record})")  
plt.xlabel(r"Standardized increment $\Delta_s B / \sigma_s$")  
plt.ylabel(r"PDF $P(\Delta_s B / \sigma_s)$")  
plt.legend(ncol=2)  
plt.grid(True, alpha=0.3, which="both", ls="--")  
plt.tight_layout()  
plt.show()

# %% [markdown]
# ## Modified addition for Step 4: Gaussian vs non-Gaussian comparison at several scales
#
# This cell compares the empirical PDF with both a Gaussian and a q-Gaussian at each requested scale.
# It also prints RSS values so the comparison is not only visual.

# %%
# modified: Gaussian vs non-Gaussian comparison at several scales for one subject
fig, axes = plt.subplots(2, 3, figsize=(16, 9), sharex=True, sharey=True)  
axes = axes.ravel()  

fit_summary_single = []  

for ax, s in zip(axes, scales_to_analyze):  
    std_inc = single_subject_increments[s]  
    x_pdf, y_pdf, popt, rss_g, rss_q = fit_q_gaussian(std_inc)  
    fit_summary_single.append((s, rss_g, rss_q, popt[2]))  

    x_plot = np.linspace(-8, 8, 500)  
    ax.plot(x_pdf, y_pdf, 'o', ms=3, alpha=0.7, label='Empirical PDF')  
    ax.plot(x_plot, norm.pdf(x_plot, 0, 1), '--', lw=2, label='Gaussian')  
    ax.plot(x_plot, q_gaussian_safe(x_plot, *popt), '-', lw=2, label=fr'q-Gaussian ($q={popt[2]:.2f}$)')  
    ax.set_yscale("log")  
    ax.set_xlim(-8, 8)  
    ax.set_ylim(1e-4, 1)  
    ax.set_title(f"modified: s = {s}")  
    ax.grid(True, alpha=0.3, which="both", ls="--")  

axes[0].legend()  
fig.suptitle(f"modified: Gaussian vs non-Gaussian comparison for one subject ({single_record})", y=1.02)  
fig.supxlabel(r"Standardized increment $\Delta_s B / \sigma_s$")  
fig.supylabel("PDF")  
plt.tight_layout()  
plt.show()  

print("modified: fit summary for one subject")  
for s, rss_g, rss_q, q_value in fit_summary_single:  
    print(f"modified: s={s:>3} | RSS Gaussian={rss_g:.6f} | RSS q-Gaussian={rss_q:.6f} | q={q_value:.3f}")
# Out:
# modified: fit summary for one subject
# modified: s=  8 | RSS Gaussian=0.535088 | RSS q-Gaussian=0.001467 | q=1.810
# modified: s= 16 | RSS Gaussian=0.406414 | RSS q-Gaussian=0.007911 | q=1.895
# modified: s= 32 | RSS Gaussian=0.295465 | RSS q-Gaussian=0.004173 | q=1.691
# modified: s= 64 | RSS Gaussian=0.280107 | RSS q-Gaussian=0.002519 | q=1.565
# modified: s=128 | RSS Gaussian=0.485266 | RSS q-Gaussian=0.003081 | q=1.573
# modified: s=256 | RSS Gaussian=0.759265 | RSS q-Gaussian=0.008293 | q=1.822

# %% [markdown]
# ## Modified addition for Step 4: Multi-subject pooled analysis
#
# This cell addresses the weakness of using only one record.
# It pools standardized increments across several subjects, scale by scale, to make the PDF results more robust.

# %%
# modified: pooled multi-subject analysis across several records
pooled_increments = {s: [] for s in scales_to_analyze}  # modified

for record in selected_records:  # modified
    B_record = B_data[record]  # modified
    for s in scales_to_analyze:  # modified
        inc = get_detrended_increments(B_record, s=s, order=3)  # modified
        pooled_increments[s].append(standardize(inc))  # modified

for s in scales_to_analyze:  # modified
    pooled_increments[s] = np.concatenate(pooled_increments[s])  # modified

# modified: pooled PDFs across subjects
plt.figure(figsize=(10, 7))  # modified
for s in scales_to_analyze:  # modified
    x_pdf, y_pdf = compute_pdf(pooled_increments[s], bins=140, x_range=(-8, 8))  # modified
    plt.plot(x_pdf, y_pdf, marker='o', ms=3, lw=1, label=f"s={s}")  # modified

plt.yscale("log")  # modified
plt.xlim(-8, 8)  # modified
plt.ylim(1e-4, 1)  # modified
plt.title(f"modified: Pooled standardized PDFs across {len(selected_records)} subjects")  # modified
plt.xlabel(r"Standardized increment $\Delta_s B / \sigma_s$")  # modified
plt.ylabel("Pooled PDF")  # modified
plt.legend(ncol=2)  # modified
plt.grid(True, alpha=0.3, which="both", ls="--")  # modified
plt.tight_layout()  # modified
plt.show()  # modified

# %% [markdown]
# This plot is the most compelling evidence that tells us the heart isn't just acting randomly! If the heart worked like a coin toss, our data points would follow the blue dashed line (the bell curve), where extreme fluctuations are basically impossible. Instead, our data follows the red line, which has 'fat tails' that stretch far out to the sides. This tells us that the heart frequently makes large, sudden adjustments that go well beyond what standard statistics predict. This 'fat-tailed' behavior is a universal signature of complex systems - like avalanches or earthquakes - that are balanced right on the edge of a critical state. It shows the heart is highly tuned, keeping itself flexible enough to respond instantly to any surprise.

# %% [markdown]
# # Step 5: The Collapse Plot

# %%
scales = [32, 64, 128, 256]
H = 1.0  # Hurst exponent for healthy heart is approx 1

first_record = list(B_data.keys())[0]

plt.figure(figsize=(8, 6))

for s in scales:
    # 1. Get the increments for this scale
    increments = get_detrended_increments(B_data[first_record], s=s, order=3)
    
    # 2. Rescale: Divide by s^H
    # This aligns the widths of the curves
    rescaled = increments / (s**H)
    
    # 3. Standardize (mean=0, std=1)
    std_rescaled = rescaled / np.std(rescaled)
    
    # 4. Build PDF
    counts, bin_edges = np.histogram(std_rescaled, bins=100, density=True)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # 5. Plot
    plt.plot(bin_centers, counts, 'o', markersize=3, label=f'Scale s={s}')

plt.yscale('log')
plt.ylim(1e-4, 1)
plt.xlim(-5, 5)
plt.title("Collapse Plot: Demonstration of Scale Invariance")
plt.xlabel("Rescaled Increments")
plt.ylabel("Probability Density (Rescaled)")
plt.legend()
plt.grid(True, alpha=0.3, which="both", ls="--")
plt.show()

# %% [markdown]
# ## Modified addition for Step 5: Improved collapse plot
#
# This cell replaces the earlier ad hoc rescaling with a cleaner comparison based on **standardized increments**.
# If the standardized PDFs for different $s$ overlap, that is stronger visual evidence for scale invariance.

# %%
# modified: better collapse plot using standardized increments, which matches the paper-style comparison more closely
plt.figure(figsize=(10, 7))  # modified

for s in scales_to_analyze:  # modified
    std_inc = pooled_increments[s]  # modified
    x_pdf, y_pdf = compute_pdf(std_inc, bins=140, x_range=(-8, 8))  # modified
    plt.plot(x_pdf, y_pdf, marker='o', ms=3, lw=1, label=f"s={s}")  # modified

plt.plot(np.linspace(-8, 8, 500), norm.pdf(np.linspace(-8, 8, 500), 0, 1), '--', lw=2, label='Gaussian reference')  # modified
plt.yscale("log")  # modified
plt.xlim(-8, 8)  # modified
plt.ylim(1e-4, 1)  # modified
plt.title("modified: Collapse plot using standardized increments across scales")  # modified
plt.xlabel(r"Standardized increment $\Delta_s B / \sigma_s$")  # modified
plt.ylabel("PDF")  # modified
plt.legend(ncol=2)  # modified
plt.grid(True, alpha=0.3, which="both", ls="--")  # modified
plt.tight_layout()  # modified
plt.show()  # modified

# %% [markdown]
# ## Modified addition for Step 5: Pooled fit summary
#
# This final cell summarizes, for the pooled multi-subject data, whether the Gaussian or q-Gaussian gives the better fit at each scale.

# %%
# modified: quantitative Gaussian vs non-Gaussian comparison for pooled multi-subject data
fit_summary_pooled = []  # modified

for s in scales_to_analyze:  # modified
    x_pdf, y_pdf, popt, rss_g, rss_q = fit_q_gaussian(pooled_increments[s])  # modified
    fit_summary_pooled.append((s, rss_g, rss_q, popt[2]))  # modified

print("modified: pooled fit summary across subjects")  # modified
for s, rss_g, rss_q, q_value in fit_summary_pooled:  # modified
    verdict = "q-Gaussian better" if rss_q < rss_g else "Gaussian better"  # modified
    print(f"modified: s={s:>3} | RSS Gaussian={rss_g:.6f} | RSS q-Gaussian={rss_q:.6f} | q={q_value:.3f} | {verdict}")  # modified
# Out:
# modified: pooled fit summary across subjects
# modified: s=  8 | RSS Gaussian=0.166232 | RSS q-Gaussian=0.000066 | q=1.679 | q-Gaussian better
# modified: s= 16 | RSS Gaussian=0.181664 | RSS q-Gaussian=0.002024 | q=1.887 | q-Gaussian better
# modified: s= 32 | RSS Gaussian=0.177214 | RSS q-Gaussian=0.004036 | q=1.806 | q-Gaussian better
# modified: s= 64 | RSS Gaussian=0.190565 | RSS q-Gaussian=0.003122 | q=1.661 | q-Gaussian better
# modified: s=128 | RSS Gaussian=0.209898 | RSS q-Gaussian=0.002158 | q=1.626 | q-Gaussian better
# modified: s=256 | RSS Gaussian=0.277451 | RSS q-Gaussian=0.004621 | q=1.751 | q-Gaussian better
